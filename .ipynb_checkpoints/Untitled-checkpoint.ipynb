# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse
mu_x = 4
mu_y = 2
rho = 0.8
sigma_x = 3.5
sigma_y = 1.5
cov = 4.2
def f(x, y, rho, mu_x, mu_y, sigma_x, sigma_y):
    return np.exp(-1/(2*(1 - rho**2))*((x - mu_x)**2 / (sigma_x**2) + (y - mu_y)**2 / (sigma_y**2) - 
                                    2*rho*(x - mu_x)*(y - mu_y)/(sigma_x*sigma_y)))
plt.grid()
x = np.linspace(-1.0, 9.0)
y = np.linspace(0, 4.0)
X, Y = np.meshgrid(x, y)
func = f(X, Y, rho, mu_x, mu_y, sigma_x, sigma_y)
plt.contourf(X, Y, func, cmap=plt.cm.viridis)
ellipse(mu=(4,2), sigma=(3.5, 1.5), alpha = .05, npoints = 250, col="red") 
plt.colorbar()
plt.show()
