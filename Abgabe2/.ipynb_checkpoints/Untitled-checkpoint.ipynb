# %% [markdown]
# # Aufgabe 6
# # a)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def randGen(a,b,m,x0):
    i = 1
    s = ((a*x0+b)%m)
    x = s
    Bool = True
    list=[s]
    while(Bool):
        x = ((a*x+b)%m)
        list.append(x)
        i +=1
        if(x==s):
            Bool = False
        if(i > 100000):
            Bool = False
            print("Abbruch")
    print("Elemente in der Liste mit ",a," : ",i)
    return i

# %%
x0 = 42
for a in range(1025):
    L = randGen(a,3,1024,x0)
# Out:
# Elemente in der Liste mit  0  :  2
# Elemente in der Liste mit  1  :  1025
# Abbruch
# Elemente in der Liste mit  2  :  100001
# Elemente in der Liste mit  3  :  513
# Abbruch
# Elemente in der Liste mit  4  :  100001
# Elemente in der Liste mit  5  :  1025
# Abbruch
# Elemente in der Liste mit  6  :  100001
# Elemente in der Liste mit  7  :  257
# Abbruch
# Elemente in der Liste mit  8  :  100001
# Elemente in der Liste mit  9  :  1025
# Abbruch
# Elemente in der Liste mit  10  :  100001
# Elemente in der Liste mit  11  :  513
# Abbruch
# Elemente in der Liste mit  12  :  100001
# Elemente in der Liste mit  13  :  1025
# Abbruch
# Elemente in der Liste mit  14  :  100001
# Elemente in der Liste mit  15  :  129
# Abbruch
# Elemente in der Liste mit  16  :  100001
# Elemente in der Liste mit  17  :  1025
# Abbruch
# Elemente in der Liste mit  18  :  100001
# Elemente in der Liste mit  19  :  513
# Abbruch
# Elemente in der Liste mit  20  :  100001
# ...

# %%
a = range(1025)
plt.plot(a,randGen(a,3,1024,x0))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-2a080a80e833> in <module>()
#       1 a = range(1025)
# ----> 2 plt.plot(a,randGen(a,3,1024,x0))
#       3 plt.show()
#
# <ipython-input-9-9dd91fc4a463> in randGen(a, b, m, x0)
#       1 def randGen(a,b,m,x0):
#       2     i = 1
# ----> 3     s = ((a*x0+b)%m)
#       4     x = s
#       5     Bool = True
#
# TypeError: unsupported operand type(s) for *: 'range' and 'int'
